# %%
# 🌍 GLOBAL HAPPINESS INDEX ANALYSIS WITH PYTHON

#AUTHOR: GEOFFREY K. RONO  
#STUDENT ID: 74199495  
#PROGRAM: MASTER OF SCIENCE IN DATA SCIENCE  
#COURSE: PS25 - DATA VISUALIZATION
#INSTRUCTOR: PROF. SAMI UR RAHMAN
#INSTITUTION: UNIVERSITY OF EUROPE FOR APPLIED SCIENCES – POTSDAM  
#DATE: JULY 2025

# %%
# 🔹 Step 1: Project Initialization
# 🪄 What to Expect:
# Importing essential Python libraries and configuring display settings for analysis.
#
# ✅ Accomplished:
# ✅ Libraries imported (pandas, numpy, matplotlib, seaborn, plotly)
# ✅ Display settings configured for clean workflow
# ---------------------------------------------------------------

# Data analysis and visualization libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Display settings for wider visibility
pd.set_option('display.max_columns', None)
plt.style.use('ggplot')

# Inline plotting for Jupyter
# %matplotlib inline

# %%
# 🔹 Step 2: Load 2015 Dataset
# 🪄 What to Expect:
# Loading the 2015 World Happiness Report for initial exploration.
#
# ✅ Accomplished:
# ✅ 2015 dataset loaded into a DataFrame
# ✅ Ready for inspection and cleaning
# ---------------------------------------------------------------

df = pd.read_csv('2015.csv')

# %%
# 🔹 Step 3: Dataset Inspection
# 🪄 What to Expect:
# Viewing column names, data types, and the first few rows to understand the structure.
#
# ✅ Accomplished:
# ✅ Columns and data types reviewed
# ✅ Structure understood for cleaning plans
# ---------------------------------------------------------------

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# 🔹 Step 4: Missing Values Check
# 🪄 What to Expect:
# Checking for missing values to assess data completeness.
#
# ✅ Accomplished:
# ✅ Missing values checked and noted
# ✅ Dataset ready for column renaming
# ---------------------------------------------------------------

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# 🔹 Step 5: Renaming Columns for 2015
# 🪄 What to Expect:
# Standardizing column names in the 2015 dataset for consistency.
#
# ✅ Accomplished:
# ✅ Column names cleaned and standardized
# ✅ Ready to merge with future datasets
# ---------------------------------------------------------------

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(r'\(.*?\)', '', regex=True)
df.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard_error  economy_   family  health_  freedom   trust_  generosity  \
# 0         0.03411   1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884   1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328   1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880   1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553   1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    dystopia_residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# ...

# %%
# 🔹 Step 6: Load Additional Years (2016–2019)
# 🪄 What to Expect:
# Loading the World Happiness Reports for 2016–2019 for multi-year analysis.
#
# ✅ Accomplished:
# ✅ 2016–2019 datasets loaded successfully
# ✅ Ready for column alignment
# ---------------------------------------------------------------

df_2016 = pd.read_csv('2016.csv')
df_2017 = pd.read_csv('2017.csv')
df_2018 = pd.read_csv('2018.csv')
df_2019 = pd.read_csv('2019.csv')

# %%
# 🔹 Step 7: Column Alignment Across Years
# 🪄 What to Expect:
# Aligning column names across all years to enable merging.
#
# ✅ Accomplished:
# ✅ Column names aligned across all datasets
# ✅ Consistent structure achieved
# ---------------------------------------------------------------

# This step is handled in my cleaning script while loading multi-year data in Step 10 (merged with loading and renaming)

# %%
# 🔹 Step 8: Adding Year Columns
# 🪄 What to Expect:
# Adding a 'year' column to each dataset for clear time tracking.
#
# ✅ Accomplished:
# ✅ Year columns added to all datasets
# ✅ Temporal tracking prepared
# ---------------------------------------------------------------

df_2016['year'] = 2016
df_2017['year'] = 2017
df_2018['year'] = 2018
df_2019['year'] = 2019

# %%
# 🔹 Step 9: Combining Datasets into `df_all`
# 🪄 What to Expect:
# Merging all years into a single DataFrame for unified analysis.
#
# ✅ Accomplished:
# ✅ All years merged into `df_all`
# ✅ Ready for cleaning and filtering
# ---------------------------------------------------------------

dfs = [df, df_2016, df_2017, df_2018, df_2019]
df_all = pd.concat(dfs, ignore_index=True)

# %%
# 🔹 Step 10: Cleaning Combined Dataset
# 🪄 What to Expect:
# Initial cleaning of `df_all` by dropping irrelevant columns and inspecting data.
#
# ✅ Accomplished:
# ✅ Dataset cleaned to retain relevant columns
# ✅ Basic structure prepared for deeper filtering
# ---------------------------------------------------------------

df_all.dropna(subset=['country', 'happiness_score'], inplace=True)
df_all.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    standard_error  economy_   family  health_  freedom   trust_  generosity  \
# 0         0.03411   1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884   1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328   1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880   1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553   1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    dystopia_residual Country Region  Happiness Rank  Happiness Score  \
# ...

# %%
# 🔹 Step 11: Data Preview
# 🪄 What to Expect:
# Previewing the cleaned dataset to confirm readiness for analysis.
#
# ✅ Accomplished:
# ✅ Shape and sample rows of `df_all` displayed
# ✅ Confirmed data is clean for visualization
# ---------------------------------------------------------------

print(df_all.shape)
df_all.head()
# Out:
# (158, 42)
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    standard_error  economy_   family  health_  freedom   trust_  generosity  \
# 0         0.03411   1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884   1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328   1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880   1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553   1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    dystopia_residual Country Region  Happiness Rank  Happiness Score  \
# ...

# %%
# 🔹 Step 12: Happiness Score Distribution (Histogram)
# 🪄 What to Expect:
# Visualizing the distribution of happiness scores globally.
#
# ✅ Accomplished:
# ✅ Histogram created for happiness scores
# ✅ Visual understanding of score spread achieved
# ---------------------------------------------------------------

plt.figure(figsize=(10, 6))
sns.histplot(df['happiness_score'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Happiness Scores (2015)', fontsize=16)
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

# %%
# 🔹 Step 13: Top 10 and Bottom 10 Happiest Countries (Final Clean)
# ---------------------------------------------------------------

# Top 10 happiest countries
top_10 = df.nlargest(10, 'happiness_score')

plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_10,
    x='happiness_score',
    y='country',
    hue='country',
    dodge=False,
    palette='Greens_r',
    legend=False
)
plt.title('Top 10 Happiest Countries (2015)', fontsize=16)
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

# Bottom 10 happiest countries
bottom_10 = df.nsmallest(10, 'happiness_score')

plt.figure(figsize=(10, 6))
sns.barplot(
    data=bottom_10,
    x='happiness_score',
    y='country',
    hue='country',
    dodge=False,
    palette='Reds_r',
    legend=False
)
plt.title('Bottom 10 Happiest Countries (2015)', fontsize=16)
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

# %%
# Check columns in 2017.csv to diagnose missing year
df_2017_check = pd.read_csv('2017.csv')
print(df_2017_check.columns)
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
# 🔹 Step 14 (Final): Clean Multi-Year Loading with All Years
# ---------------------------------------------------------------

import pandas as pd

years = [2015, 2016, 2017, 2018, 2019]
dfs = []

for year in years:
    file_name = f'{year}.csv'
    df_year = pd.read_csv(file_name)
    df_year['year'] = year

    # Normalize column names BEFORE selection
    df_year.columns = df_year.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(r'[().]', '', regex=True)

    rename_map = {
        'country_or_region': 'country',
        'score': 'happiness_score',
        'happinessscore': 'happiness_score',
        'economygdppercapita': 'economy_gdp_per_capita',
        'social_support': 'family',
        'healthylife_expectancy': 'health_life_expectancy',
        'healthlife_expectancy': 'health_life_expectancy',
        'freedomtomakelifechoices': 'freedom',
        'trustgovernmentcorruption': 'trust_government_corruption',
        'perceptionsofcorruption': 'trust_government_corruption',
    }
    df_year = df_year.rename(columns=rename_map)

    # Filter to required columns if present
    required_columns = ['country', 'happiness_score', 'economy_gdp_per_capita',
                        'family', 'health_life_expectancy', 'freedom',
                        'trust_government_corruption', 'generosity', 'year']

    df_year = df_year[[col for col in required_columns if col in df_year.columns]]

    dfs.append(df_year)

# Concatenate all years
df_all = pd.concat(dfs, ignore_index=True)

# Drop rows missing critical values
df_all = df_all.dropna(subset=['country', 'happiness_score'])

# Export to CSV for your Streamlit dashboard
df_all.to_csv('merged_happiness_data.csv', index=False)

# Confirm structure
print("Shape of merged dataset:", df_all.shape)
print("Available years:", sorted(df_all['year'].unique()))
df_all.head()
# Out:
# Shape of merged dataset: (782, 9)
# Available years: [np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019)]
#        country  happiness_score  economy_gdp_per_capita   family  \
# 0  Switzerland            7.587                 1.39651  1.34951
# 1      Iceland            7.561                 1.30232  1.40223
# 2      Denmark            7.527                 1.32548  1.36058
# 3       Norway            7.522                 1.45900  1.33095
# 4       Canada            7.427                 1.32629  1.32261
#
#    health_life_expectancy  freedom  trust_government_corruption  generosity  \
# 0                 0.94143  0.66557                      0.41978     0.29678
# 1                 0.94784  0.62877                      0.14145     0.43630
# 2                 0.87464  0.64938                      0.48357     0.34139
# 3                 0.88521  0.66973                      0.36503     0.34699
# ...

# %%
# Check columns in 2017.csv
import pandas as pd

df_2017 = pd.read_csv('2017.csv')
print(df_2017.columns)
df_2017.head()
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# ...

# %%
# 🔹 Step 15A: Column Standardization & Filtering
# 🪄 What to Expect:
# Refines df_all with consistent column names,
# filters relevant columns, drops rows with missing data.
# ---------------------------------------------------------------

# Clean and standardize column names
df_all.columns = df_all.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(r'\(.*?\)', '', regex=True)

# Define required columns explicitly
required_columns = [
    'country', 'happiness_score', 'economy_gdp_per_capita',
    'family', 'health_life_expectancy', 'freedom',
    'trust_government_corruption', 'generosity', 'year'
]

# Filter columns if they exist
df_all = df_all[[col for col in required_columns if col in df_all.columns]]

# Drop missing values in critical columns
df_all = df_all.dropna(subset=['country', 'happiness_score'])

# Confirm structure
print("✅ Step 15A complete. Clean dataset ready.")
print("Shape:", df_all.shape)
print("Available years:", df_all['year'].unique())
df_all.head()
# Out:
# ✅ Step 15A complete. Clean dataset ready.
# Shape: (782, 9)
# Available years: ['2015' '2016' '2017' '2018' '2019']
#        country  happiness_score  economy_gdp_per_capita   family  \
# 0  Switzerland            7.587                 1.39651  1.34951
# 1      Iceland            7.561                 1.30232  1.40223
# 2      Denmark            7.527                 1.32548  1.36058
# 3       Norway            7.522                 1.45900  1.33095
# 4       Canada            7.427                 1.32629  1.32261
#
#    health_life_expectancy  freedom  trust_government_corruption  generosity  \
# 0                 0.94143  0.66557                      0.41978     0.29678
# 1                 0.94784  0.62877                      0.14145     0.43630
# 2                 0.87464  0.64938                      0.48357     0.34139
# 3                 0.88521  0.66973                      0.36503     0.34699
# 4                 0.90563  0.63297                      0.32957     0.45811
#
# ...

# %%
# Remove duplicate columns by keeping the first occurrence
df_all = df_all.loc[:, ~df_all.columns.duplicated()]

# Confirm cleanup
print("Columns after removing duplicates:", df_all.columns.tolist())
# Out:
# Columns after removing duplicates: ['country', 'happiness_score', 'economy_gdp_per_capita', 'family', 'health_life_expectancy', 'freedom', 'trust_government_corruption', 'generosity', 'year']

# %%
import pandas as pd

for year in [2015, 2016, 2017, 2018, 2019]:
    df_check = pd.read_csv(f"{year}.csv")
    print(year, df_check.shape)
# Out:
# 2015 (158, 12)
# 2016 (157, 13)
# 2017 (155, 12)
# 2018 (156, 9)
# 2019 (156, 9)

# %%
# 🔹 Step 15B: Year-over-Year Analysis (Clean, Future-Proof)
# 🪄 What to Expect:
# (a) Box plot to visualize the overall happiness score distribution by year.
# (b) Line plot to track top 5 happiest countries from 2015 across 2015–2019.
#
# ✅ Accomplished:
# ✅ Boxplot without seaborn FutureWarning.
# ✅ Clean top 5 year-over-year trends plot.
# ✅ Ready for slides and GitHub documentation.
# ---------------------------------------------------------------

import matplotlib.pyplot as plt
import seaborn as sns

# 15B (a): Box plot - Happiness Score Distribution by Year
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=df_all,
    x='year',
    y='happiness_score',
    hue='year',
    palette='Set3',
    legend=False  # avoids redundant legend
)
plt.title('Happiness Score Distribution by Year')
plt.xlabel('Year')
plt.ylabel('Happiness Score')
plt.show()

# 15B (b): Line plot - Year-over-Year Happiness Trend for Top 5 Countries
# Identify the top 5 countries in 2015
top5_2015 = df_all[df_all['year'] == 2015].nlargest(5, 'happiness_score')['country'].tolist()
print("Top 5 Countries in 2015:", top5_2015)

# Filter dataset for these countries across all years
df_top5 = df_all[df_all['country'].isin(top5_2015)]

plt.figure(figsize=(10, 6))
sns.lineplot(
    data=df_top5,
    x='year',
    y='happiness_score',
    hue='country',
    marker='o'
)
plt.title('Year-over-Year Happiness Trend for Top 5 Countries (2015–2019)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Happiness Score')
plt.legend(title='Country')
plt.show()
# Out:
# Top 5 Countries in 2015: ['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada']

# %%
#Verify Year Completeness:

import pandas as pd
df = pd.read_csv('merged_happiness_data.csv')
print(df['year'].unique())
# Out:
# [2015 2016 2017 2018 2019]

# %%
# 🔹 Step 16: Correlation Heatmap
# 🪄 What to Expect:
# Compute and visualize the correlation matrix between numeric features
# in the happiness dataset to observe feature relationships and dependencies.
#
# ✅ Accomplished:
# ✅ Correlation matrix calculated
# ✅ Heatmap visualized with clear annotations and color scale
# ✅ Useful for identifying which factors correlate most with happiness
# ---------------------------------------------------------------

import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns for correlation calculation
numeric_df = df_all.select_dtypes(include='number')

# Compute correlation matrix
correlation = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8},
    annot_kws={"size": 10}
)
plt.title('Correlation Heatmap of Global Happiness Indicators (2015–2019)', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# 🔹 Step 17: Animated Choropleth Map
# 🪄 What to Expect:
# Displays an interactive, animated choropleth map of happiness scores
# across countries for each year (2015–2019).
#
# ✅ Accomplished:
# ✅ Interactive map with year slider
# ✅ Countries colored by happiness_score
# ✅ Color scale: lower (purple) to higher (yellow/green) happiness
# ✅ Suitable for inclusion in dashboard or slides
# ---------------------------------------------------------------

import plotly.express as px

# Ensure 'year' column is of type str for clear slider display
df_all['year'] = df_all['year'].astype(str)

fig = px.choropleth(
    df_all,
    locations='country',
    locationmode='country names',
    color='happiness_score',
    hover_name='country',
    animation_frame='year',
    color_continuous_scale='Viridis',
    title='Animated Global Happiness Scores (2015–2019)',
    height=600
)

fig.update_layout(
    coloraxis_colorbar=dict(
        title="Happiness Score",
        tickvals=[3, 4, 5, 6, 7, 8],
        ticktext=["3", "4", "5", "6", "7", "8"]
    )
)

fig.show()

# %%
# 🔹 Step 18: Dashboard Preparation with Streamlit
# 🪄 What to Expect:
# Build an interactive dashboard using Streamlit to explore global happiness data
# for your slides, demos, and GitHub portfolio.
#
# ✅ Accomplished:
# ✅ Year selector and data preview
# ✅ Histogram of happiness scores
# ✅ Top 10 happiest countries bar plot
# ✅ Correlation heatmap
# ✅ Ready for extension with maps and advanced analysis
# ---------------------------------------------------------------

# 🩶 Instructions for Step 18:

# ✅ 1️⃣ Create your dashboard file:
# In your terminal inside your project folder, run:
# code global_happiness_dashboard.py

# ✅ 2️⃣ Paste the following clean Streamlit code in the file:

# ---------------------------------------------------------------
# import streamlit as st
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# st.set_page_config(page_title="Global Happiness Dashboard", layout="wide")

# df_all = pd.read_csv('merged_happiness_data.csv')

# st.title("🌍 Global Happiness Dashboard (2015–2019)")

# years = sorted(df_all['year'].unique())
# selected_year = st.selectbox("Select Year:", years, index=0)
# df_year = df_all[df_all['year'] == selected_year]

# st.subheader(f"Data for {selected_year}")
# st.dataframe(df_year.head(20))

# st.subheader("Distribution of Happiness Scores")
# fig, ax = plt.subplots(figsize=(8, 5))
# sns.histplot(df_year['happiness_score'], bins=20, kde=True, ax=ax, color='skyblue')
# ax.set_xlabel("Happiness Score")
# ax.set_ylabel("Frequency")
# st.pyplot(fig)

# st.subheader("Top 10 Happiest Countries")
# top_10 = df_year.nlargest(10, 'happiness_score')
# fig, ax = plt.subplots(figsize=(8, 5))
# sns.barplot(data=top_10, x='happiness_score', y='country', palette='viridis', ax=ax)
# ax.set_xlabel("Happiness Score")
# ax.set_ylabel("Country")
# st.pyplot(fig)

# st.subheader("Correlation Heatmap")
# numeric_df = df_year.select_dtypes(include='number')
# correlation = numeric_df.corr()
# fig, ax = plt.subplots(figsize=(8, 6))
# sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", ax=ax)
# st.pyplot(fig)

# st.info("✅ Dashboard is ready for exploration and further expansion with maps and advanced analytics.")
# ---------------------------------------------------------------

# ✅ 3️⃣ Run your dashboard:
# In your terminal:
# streamlit run global_happiness_dashboard.py

# 🚀 What this achieves:
# ✅ Clean, interactive dashboard for year-by-year exploration
# ✅ Visualizes distributions, top countries, and correlations
# ✅ Ready for your GitHub portfolio and presentations

# ---------------------------------------------------------------
# ✅ Step 18 preparation documented cleanly.
# Proceed to Step 19 for advanced modeling and evaluation.
# ---------------------------------------------------------------

# %%
# Reload merged multi-year dataset for analysis
import pandas as pd

df_all = pd.read_csv('merged_happiness_data.csv')

print("✅ merged_happiness_data.csv loaded successfully.")
print(df_all.head())
# Out:
# ✅ merged_happiness_data.csv loaded successfully.
#        country  happiness_score  economy_gdp_per_capita   family  \
# 0  Switzerland            7.587                 1.39651  1.34951
# 1      Iceland            7.561                 1.30232  1.40223
# 2      Denmark            7.527                 1.32548  1.36058
# 3       Norway            7.522                 1.45900  1.33095
# 4       Canada            7.427                 1.32629  1.32261
#
#    health_life_expectancy  freedom  trust_government_corruption  generosity  \
# 0                 0.94143  0.66557                      0.41978     0.29678
# 1                 0.94784  0.62877                      0.14145     0.43630
# 2                 0.87464  0.64938                      0.48357     0.34139
# 3                 0.88521  0.66973                      0.36503     0.34699
# 4                 0.90563  0.63297                      0.32957     0.45811
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
# 🔹 Step 19: Advanced Insights and Predictive Modeling (Final Clean)
# 🪄 What to Expect:
# - Train Linear Regression on cleaned multi-year dataset
# - Visualize feature importance, predicted vs actual, residuals
# - Output evaluation metrics (MSE, R²)
# ---------------------------------------------------------------

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Features for prediction
features = [
    'economy_gdp_per_capita',
    'family',
    'health_life_expectancy',
    'freedom',
    'trust_government_corruption',
    'generosity'
]

# Clean and prepare data
df_clean = df_all.dropna(subset=features + ['happiness_score'])
X = df_clean[features]
y = df_clean['happiness_score']

# Train Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Feature Importance Plot (future-proof)
importance = model.coef_
plt.figure(figsize=(10, 6))
sns.barplot(x=importance, y=features, hue=features, palette='viridis', dodge=False, legend=False)
plt.title('Feature Importance on Happiness Score (Linear Regression)')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# Predicted vs Actual Plot
y_pred = model.predict(X)
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--r')
plt.xlabel('Actual Happiness Score')
plt.ylabel('Predicted Happiness Score')
plt.title('Predicted vs Actual Happiness Scores')
plt.show()

# Residual Distribution Plot
residuals = y - y_pred
plt.figure(figsize=(8, 6))
sns.histplot(residuals, bins=30, kde=True, color='skyblue')
plt.title('Residual Distribution (Predicted - Actual)')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# Evaluation Metrics
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print("✅ Step 19 Complete")
print(f"Mean Squared Error: {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")
# Out:
# ✅ Step 19 Complete
# Mean Squared Error: 0.3031
# R^2 Score: 0.7666

# %%
print(df_all['year'].unique())
# Out:
# [2015 2016 2017 2018 2019]
